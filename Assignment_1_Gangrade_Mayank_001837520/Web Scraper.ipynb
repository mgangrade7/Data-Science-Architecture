# %% [markdown]
# ### Web Scraper
# website : http://www.che.neu.edu/
#
# Operations:
# * Collect all of the external links (there must be some on the page of your )
# * Associate the link with a textual description of it from the website.
# * Write a function to check whether the link is valid.
# * Save the external links(urls), textual description, a boolean for valid, and the last vaild datetime check to an excel file.

# %%
from __future__ import print_function
import urllib3 #  pip install -i https://pypi.anaconda.org/pypi/simple urllib3
import unicodedata
import requests
from bs4 import BeautifulSoup, SoupStrainer, Comment
import warnings
warnings.filterwarnings('ignore')

# %%
# To get the response from thr URL Server
url = 'http://www.che.neu.edu/'
http = urllib3.PoolManager()
response = http.request('GET',url)
response.status
# Out:
# 200

# %%
page = requests.get('http://www.che.neu.edu/')
soup = BeautifulSoup(page.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8">
#    <meta content="width=device-width" name="viewport"/>
#    <link href="http://www.che.neu.edu/sites/default/files/favicon.ico" rel="shortcut icon"/>
#    <meta content="false" http-equiv="ImageToolbar"/>
#    <link href="https://fast.fonts.com/cssapi/cac43e8c-6965-44df-b8ca-9784607a3b53.css" rel="stylesheet"/>
#    <meta content="5Vofdey1DjnJu8erp0SF4kFkF-jhjjE1qdeB3xZmgzo" name="google-site-verification"/>
#    <meta content="Northeastern University's College of Engineering, which is located in Boston, Massachusetts, is leading the way in interdisciplinary research." name="description"/>
#    <meta content="Drupal 7 (http://drupal.org)" name="generator"/>
#    <link href="http://www.che.neu.edu/" rel="canonical"/>
#    <link href="http://www.che.neu.edu/" rel="shortlink"/>
#    <title>
#     Chemical Engineering | Northeastern University |
#    </title>
#    <link href="http://www.che.neu.edu/sites/default/files/css/css_kShW4RPmRstZ3SpIC-ZvVGNFVAi0WEMuCnI0ZkYIaFw.css" rel="stylesheet"/>
#    <link href="http://www.che.neu.edu/sites/default/files/css/css_oELodZ_SfWD8iYw2z2mPHCZlMOXzs3IrTTmzGXogilY.css" rel="stylesheet"/>
#    <link href="http://www.che.neu.edu/sites/default/files/css/css_HmtHS3MI9322KaBqY1KHQe734s4nqKup7pxxwLridEg.css" rel="stylesheet"/>
#    <link href="http://www.che.neu.edu/sites/default/files/css/css_uth0K65AUruAd9Cip9yz2LqEEqq-117_Pm4VKHYCRZE.css" rel="stylesheet"/>
#    <script src="http://www.che.neu.edu/sites/default/files/js/js_hbCs-Jp4M77A5aKC8_pY18-frLS-3JEeApksrZsRZlU.js">
#    </script>
#    <script>
#     document.createElement( "picture" );
#    </script>
#    <script src="http://www.che.neu.edu/sites/default/files/js/js_JvqhpI7zKZft6BM8kkDMe7jOKkTy0JFmYd3BHZkfhKo.js">
#    </script>
#    <script>
#     window.CKEDITOR_BASEPATH = '/sites/all/libraries/ckeditor/'
#    </script>
#    <script src="http://www.che.neu.edu/sites/default/files/js/js_gPqjYq7fqdMzw8-29XWQIVoDSWTmZCGy9OqaHppNxuQ.js">
#    </script>
#    <script>
#     (function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","//www.google-analytics.com/analytics.js","ga");ga("create", "UA-1768083-1", {"cookieDomain":".neu.edu"});ga("send", "pageview");
#    </script>
#    <script src="http://www.che.neu.edu/sites/default/files/js/js_YVZPapNwyadeewv2ZZJsGWo1-qKzKWHXgyL6XXbe7o8.js">
#    </script>
#    <script src="http://www.che.neu.edu/sites/default/files/js/js_jhXz1Zc0subAH6frMl9CuOzVURmjkEnyQ_Zek1v0Zx4.js">
#    </script>
#    <script>
#     jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"nucoe","theme_token":"g_sEDGItx59MBxMSpZcErIW_f93pvss8CSEla-xEvhM","js":{"sites\/all\/modules\/contrib\/picture\/picturefill2\/picturefill.min.js":1,"sites\/all\/modules\/contrib\/picture\/picture.min.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/jquery\/1.7\/jquery.min.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"0":1,"sites\/all\/modules\/contrib\/google_cse\/google_cse.js":1,"sites\/all\/modules\/custom\/nucoe_custom_front\/js\/nucoe_custom_front.js":1,"sites\/all\/modules\/custom\/nucoe_custom_menus\/js\/top-navigation.js":1,"sites\/all\/modules\/custom\/nucoe_custom_menus\/js\/hamburger-menu.js":1,"1":1,"sites\/all\/modules\/contrib\/google_analytics\/googleanalytics.js":1,"2":1,"sites\/all\/libraries\/cycle2\/cycle2.min.js":1,"sites\/all\/modules\/custom\/nucoe_custom_sliders\/js\/nucoe_custom_sliders.js":1,"sites\/all\/themes\/nucoe\/js\/vendor\/custom.modernizr.js":1,"sites\/all\/themes\/nucoe\/js\/foundation.min.js":1,"sites\/all\/themes\/nucoe\/js\/vendor\/jquery.placeholder.js":1,"sites\/all\/themes\/nucoe\/js\/scripts.js":1,"sites\/all\/themes\/nucoe\/js\/gsap\/TweenMax.min.js":1,"sites\/all\/themes\/nucoe\/js\/home_redesign.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"sites\/all\/modules\/contrib\/calendar\/css\/calendar_multiday.css":1,"sites\/all\/modules\/contrib\/date\/date_api\/date.css":1,"sites\/all\/modules\/contrib\/date\/date_popup\/themes\/datepicker.1.7.css":1,"modules\/field\/theme\/field.css":1,"sites\/all\/modules\/contrib\/google_cse\/google_cse.css":1,"modules\/node\/node.css":1,"sites\/all\/modules\/custom\/oho_date_block\/css\/oho_date_block.css":1,"sites\/all\/modules\/contrib\/picture\/picture_wysiwyg.css":1,"modules\/search\/search.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/contrib\/views\/css\/views.css":1,"sites\/all\/modules\/contrib\/ctools\/css\/ctools.css":1,"sites\/all\/modules\/contrib\/shib_auth\/shib_auth.css":1,"sites\/all\/modules\/contrib\/field_collection\/field_collection.theme.css":1,"sites\/all\/themes\/zurb-foundation\/css\/normalize.css":1,"sites\/all\/themes\/nucoe\/css\/foundation.min.css":1,"sites\/all\/themes\/nucoe\/css\/nucoe.css":1,"sites\/all\/themes\/nucoe\/fonts\/fontawesome\/web-fonts-with-css\/css\/fontawesome-all.css":1,"sites\/all\/themes\/nucoe\/css\/stylesheet.css":1}},"googleCSE":{"cx":"010955025314345514182:vosmbbxchsq","language":"","resultsWidth":600,"domain":"www.google.com","showWaterMark":true},"urlIsAjaxTrusted":{"\/":true},"googleanalytics":{"trackOutbound":1,"trackMailto":1,"trackDownload":1,"trackDownloadExtensions":"7z|aac|arc|arj|asf|asx|avi|bin|csv|doc(x|m)?|dot(x|m)?|exe|flv|gif|gz|gzip|hqx|jar|jpe?g|js|mp(2|3|4|e?g)|mov(ie)?|msi|msp|pdf|phps|png|ppt(x|m)?|pot(x|m)?|pps(x|m)?|ppam|sld(x|m)?|thmx|qtm?|ra(m|r)?|sea|sit|tar|tgz|torrent|txt|wav|wma|wmv|wpd|xls(x|m|b)?|xlt(x|m)|xlam|xml|z|zip","trackDomainMode":"1"},"currentPath":"node\/6","currentPathIsAdmin":false,"ogContext":{"groupType":"node","gid":"6"}});
#    </script>
#    <!--[if lt IE 9]>
#     <script src="http://html5shiv.googlecode.com/svn/trunk/html5.js"></script>
#   <![endif]-->
#    <!--[if (gte IE 6)&(lte IE 8)]>
#       <script src="//cdnjs.cloudflare.com/ajax/libs/html5shiv/3.6.2/html5shiv.js"></script>
#       <script src="//s3.amazonaws.com/nwapi/nwmatcher/nwmatcher-1.2.5-min.js"></script>
#       <script src="//html5base.googlecode.com/svn-history/r38/trunk/js/selectivizr-1.0.3b.js"></script>
#       <script src="/sites/all/themes/nucoe/js/respond.min.js"></script>
#       <script src="/sites/all/themes/nucoe/js/rem.min.js" type="text/javascript"></script>
#       <script src="js/placeholders.js" type="text/javascript"></script>
#     <![endif]-->
#   </meta>
#  </head>
#  <body class="html front not-logged-in one-sidebar sidebar-second page-node page-node- page-node-6 node-type-department domain-nucoe-che og-context og-context-node og-context-node-6">
#   <!-- Google Tag Manager -->
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-WGQLLJ" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push(
#   {'gtm.start': new Date().getTime(),event:'gtm.js'}
#   );var f=d.getElementsByTagName(s)[0],
#   j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#   '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#   })(window,document,'script','dataLayer','GTM-WGQLLJ');
#   </script>
#   <!-- End Google Tag Manager -->
#   <div class="skip-link">
#    <a class="element-invisible element-focusable" href="#main-content">
#     Skip to main content
#    </a>
#   </div>
#   <!--.page -->
#   <div class="page" role="document">
#    <!--.l-header region -->
#    <header class="l-header" role="banner">
#     <!--.l-header-region -->
#     <section class="l-header-region row">
#      <div class="large-12 columns">
#       <!-- Logo -->
#       <div id="nucoe-logo">
#        <a href="http://www.coe.neu.edu/" rel="home" title="Home">
#         <img alt=" logo" class="logo" src="http://www.che.neu.edu/sites/all/themes/nucoe/images/nucoe-logo.jpg" title=" Home"/>
#        </a>
#       </div>
#       <!-- End Logo -->
#       <section class="block block-nucoe-custom-menus block-nucoe-custom-menus-mobile-buttons header">
#        <div id="search-button-mobile">
#        </div>
#        <div class="hamburger-menu">
#         <div id="hamburger-menu-button">
#         </div>
#         <div class="hamburger-nav">
#          <div class="department" id="hamburger-menu-wrapper">
#           <div class="department" id="hamburger-menu-nav-panel">
#            Back to College Menu
#           </div>
#           <div id="department-panel">
#            <ul class="menu">
#             <li class="first expanded menu-mlid-962">
#              <div class="expand-collapse">
#               ▼
#              </div>
#              <a href="/che/about-chemical-engineering">
#               About
#              </a>
#              <ul class="menu">
#               <li class="first leaf menu-mlid-1424">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="/che/mission-statement">
#                 Mission Statement
#                </a>
#               </li>
#               <li class="leaf menu-mlid-2425">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="/che/about/message-chair">
#                 Message from the Chair
#                </a>
#               </li>
#               <li class="leaf menu-mlid-1408">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="/che/department-history">
#                 Department History
#                </a>
#               </li>
#               <li class="leaf menu-mlid-1404">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="/che/contact-us">
#                 Contact Us
#                </a>
#               </li>
#               <li class="leaf menu-mlid-1144">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="/che/about/directory">
#                 Directory
#                </a>
#               </li>
#               <li class="last leaf menu-mlid-1139">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="/che/success">
#                 Success Stories
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li class="expanded menu-mlid-967">
#              <div class="expand-collapse">
#               ▼
#              </div>
#              <a href="/che/degrees-programs">
#               Degrees &amp; Programs
#              </a>
#              <ul class="menu">
#               <li class="first expanded menu-mlid-1661">
#                <div class="expand-collapse">
#                 ▼
#                </div>
#                <a href="/che/degrees-programs/undergraduate-studies">
#                 Undergraduate Studies
#                </a>
#                <ul class="menu">
#                 <li class="first leaf menu-mlid-1604">
#                  <div class="expand-collapse disabled">
#                  </div>
#                  <a href="/degrees/biochemical-engineering-minor">
#                   Minor, Biochemical Engineering
#                  </a>
#                 </li>
#                 <li class="leaf menu-mlid-1783">
#                  <div class="expand-collapse disabled">
#                  </div>
#                  <a href="/degrees/materials-science-and-engineering-minor">
#                   Minor, Materials Science &amp; Engineering
#                  </a>
#                 </li>
#                 <li class="leaf menu-mlid-1605">
#                  <div class="expand-collapse disabled">
#                  </div>
#                  <a href="/degrees/chemical-engineering-bs">
#                   BS, Chemical Engineering
#                  </a>
#                 </li>
#                 <li class="leaf menu-mlid-1610">
#                  <div class="expand-collapse disabled">
#                  </div>
#                  <a href="/degrees/chemical-engineering-and-physics-bs">
#                   BS, Chemical Engineering &amp; Physics
#                  </a>
#                 </li>
#                 <li class="leaf menu-mlid-1606">
#                  <div class="expand-collapse disabled">
#                  </div>
#                  <a href="/degrees/plusone-bs/ms-chemical-engineering">
#                   BS/MS, Chemical Engineering
#                  </a>
#                 </li>
#                 <li class="leaf menu-mlid-3787">
#                  <div class="expand-collapse disabled">
#                  </div>
#                  <a href="http://www.mie.neu.edu/degrees/plusone-bs/ms-engineering-management">
#                   BS/MS, Engineering Management
#                  </a>
#                 </li>
#                 <li class="leaf menu-mlid-1407">
#                  <div class="expand-collapse disabled">
#                  </div>
#                  <a href="/che/undergraduate-studies/accreditation">
#                   Accreditation
#                  </a>
#                 </li>
#                 <li class="last leaf menu-mlid-1406">
#                  <div class="expand-collapse disabled">
#                  </div>
#                  <a href="/che/capstone">
#                   Capstone
#                  </a>
#                 </li>
#                </ul>
#               </li>
#               <li class="last expanded menu-mlid-1611">
#                <div class="expand-collapse">
#                 ▼
#                </div>
#                <a href="/che/degrees-programs/graduate-studies">
#                 Graduate Studies
#                </a>
#                <ul class="menu">
#                 <li class="first leaf menu-mlid-1607">
#                  <div class="expand-collapse disabled">
#                  </div>
#                  <a href="/degrees/master-science-chemical-engineering">
#                   MS, Chemical Engineering
#                  </a>
#                 </li>
#                 <li class="last leaf menu-mlid-1608">
#                  <div class="expand-collapse disabled">
#                  </div>
#                  <a href="/degrees/chemical-engineering-phd">
#                   PhD, Chemical Engineering
#                  </a>
#                 </li>
#                </ul>
#               </li>
#              </ul>
#             </li>
#             <li class="expanded menu-mlid-977">
#              <div class="expand-collapse">
#               ▼
#              </div>
#              <a href="/che/co-op-experiential-learning">
#               Co-op &amp; Experiential Learning
#              </a>
#              <ul class="menu">
#               <li class="first leaf menu-mlid-1422">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.northeastern.edu/coop/students/faq/">
#                 Co-op FAQs
#                </a>
#               </li>
#               <li class="expanded menu-mlid-1426">
#                <div class="expand-collapse">
#                 ▼
#                </div>
#                <a href="/che/exchange-program">
#                 Exchange Program
#                </a>
#                <ul class="menu">
#                 <li class="first last leaf menu-mlid-3109">
#                  <div class="expand-collapse disabled">
#                  </div>
#                  <a href="/che/exchange-program/exchange-program-past-research-projects">
#                   Exchange Program - Past Research Projects
#                  </a>
#                 </li>
#                </ul>
#               </li>
#               <li class="leaf menu-mlid-1521">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="/che/student-industry-bridge">
#                 Student-Industry Bridge
#                </a>
#               </li>
#               <li class="leaf menu-mlid-3502">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="/che/co-op-experiential-learning/co-op-coordinators">
#                 Co-op Coordinators
#                </a>
#               </li>
#               <li class="last leaf menu-mlid-4839">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="/che/co-op-experiential-learning/international-research">
#                 International Research
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li class="expanded menu-mlid-982">
#              <div class="expand-collapse">
#               ▼
#              </div>
#              <a href="/che/faculty-research">
#               Faculty &amp; Research
#              </a>
#              <ul class="menu">
#               <li class="first expanded menu-mlid-4179">
#                <div class="expand-collapse">
#                 ▼
#                </div>
#                <a href="/che/faculty-research/faculty">
#                 Faculty
#                </a>
#                <ul class="menu">
#                 <li class="first leaf menu-mlid-2117">
#                  <div class="expand-collapse disabled">
#                  </div>
#                  <a href="/che/faculty/directory">
#                   Faculty Directory
#                  </a>
#                 </li>
#                 <li class="leaf menu-mlid-2717">
#                  <div class="expand-collapse disabled">
#                  </div>
#                  <a href="/che/faculty-directory/honors-and-distinctions">
#                   Honors and Distinctions
#                  </a>
#                 </li>
#                 <li class="last leaf menu-mlid-2429">
#                  <div class="expand-collapse disabled">
#                  </div>
#                  <a href="/che/faculty/scholarship-reports">
#                   Scholarship Reports
#                  </a>
#                 </li>
#                </ul>
#               </li>
#               <li class="last expanded menu-mlid-1412">
#                <div class="expand-collapse">
#                 ▼
#                </div>
#                <a href="/che/research-areas">
#                 Research Areas
#                </a>
#                <ul class="menu">
#                 <li class="first leaf menu-mlid-2121">
#                  <div class="expand-collapse disabled">
#                  </div>
#                  <a href="/che/research/advanced-materials">
#                   Advanced Materials Research
#                  </a>
#                 </li>
#                 <li class="last leaf menu-mlid-2122">
#                  <div class="expand-collapse disabled">
#                  </div>
#                  <a href="/che/research/biological-engineering">
#                   Biological Engineering
#                  </a>
#                 </li>
#                </ul>
#               </li>
#              </ul>
#             </li>
#             <li class="expanded menu-mlid-972">
#              <div class="expand-collapse">
#               ▼
#              </div>
#              <a href="/che/community">
#               Community
#              </a>
#              <ul class="menu">
#               <li class="first leaf menu-mlid-2942">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="/che/newsletters">
#                 Alumni Newsletters
#                </a>
#               </li>
#               <li class="leaf menu-mlid-1423">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="/che/alumni">
#                 IAB Directory
#                </a>
#               </li>
#               <li class="leaf menu-mlid-1409">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="/che/community/orgs">
#                 Student Groups
#                </a>
#               </li>
#               <li class="leaf menu-mlid-3765">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="/che/community/writing-center">
#                 Writing Center
#                </a>
#               </li>
#               <li class="last leaf menu-mlid-4302">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.nuche1on1.com/">
#                 1on1 Mentoring
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li class="last expanded menu-mlid-1414">
#              <div class="expand-collapse">
#               ▼
#              </div>
#              <a href="/che/news-events">
#               News &amp; Events
#              </a>
#              <ul class="menu">
#               <li class="first expanded menu-mlid-1070">
#                <div class="expand-collapse">
#                 ▼
#                </div>
#                <a href="/academics/depts/chemical-engineering/news">
#                 News
#                </a>
#                <ul class="menu">
#                 <li class="first leaf menu-mlid-4817">
#                  <div class="expand-collapse disabled">
#                  </div>
#                  <a href="/che/in-the-media">
#                   In the Media
#                  </a>
#                 </li>
#                 <li class="leaf menu-mlid-4816">
#                  <div class="expand-collapse disabled">
#                  </div>
#                  <a href="/che/blog">
#                   Blog
#                  </a>
#                 </li>
#                 <li class="collapsed menu-mlid-1425">
#                  <div class="expand-collapse disabled">
#                  </div>
#                  <a href="/che/award-ceremonies">
#                   Award Ceremonies
#                  </a>
#                 </li>
#                 <li class="last leaf menu-mlid-1787">
#                  <div class="expand-collapse disabled">
#                  </div>
#                  <a href="/che/newsletters">
#                   Newsletters
#                  </a>
#                 </li>
#                </ul>
#               </li>
#               <li class="last expanded menu-mlid-1523">
#                <div class="expand-collapse">
#                 ▼
#                </div>
#                <a href="/che/events">
#                 Events
#                </a>
#                <ul class="menu">
#                 <li class="first last leaf menu-mlid-1427">
#                  <div class="expand-collapse disabled">
#                  </div>
#                  <a href="/che/guest-graduate-seminars">
#                   Guest &amp; Graduate Seminars
#                  </a>
#                 </li>
#                </ul>
#               </li>
#              </ul>
#             </li>
#            </ul>
#           </div>
#           <div class="hidden" id="college-panel">
#            <ul class="menu">
#             <li class="first expanded menu-mlid-3230">
#              <div class="expand-collapse">
#               ▼
#              </div>
#              <a href="http://www.coe.neu.edu/why-coe/about-college">
#               About
#              </a>
#              <ul class="menu">
#               <li class="first leaf menu-mlid-3505">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.coe.neu.edu/why-coe">
#                 Why COE?
#                </a>
#               </li>
#               <li class="leaf menu-mlid-2947">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.coe.neu.edu/why-coe/engineering-leadership">
#                 College Leadership
#                </a>
#               </li>
#               <li class="leaf menu-mlid-3745">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.coe.neu.edu/about-college/prospective-students">
#                 Info for Prospective Students
#                </a>
#               </li>
#               <li class="leaf menu-mlid-3746">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.coe.neu.edu/about-college/current-students">
#                 Info for Current Students
#                </a>
#               </li>
#               <li class="leaf menu-mlid-3747">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.coe.neu.edu/about-college/faculty-staff">
#                 Info for Faculty &amp; Staff
#                </a>
#               </li>
#               <li class="last leaf menu-mlid-3748">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.coe.neu.edu/about-college/corporate-partners">
#                 Info for Corporate Partners
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li class="collapsed menu-mlid-957">
#              <div class="expand-collapse disabled">
#              </div>
#              <a href="http://www.coe.neu.edu/co-op-experiential-learning">
#               Co-op &amp; Experiential Learning
#              </a>
#             </li>
#             <li class="last collapsed menu-mlid-960">
#              <div class="expand-collapse disabled">
#              </div>
#              <a href="http://www.coe.neu.edu/news-events">
#               News &amp; Events
#              </a>
#             </li>
#            </ul>
#            <form accept-charset="UTF-8" action="/" id="nucoe-custom-menus-form" method="post">
#             <div>
#              <div class="form-item form-type-select form-item-menu">
#               <select class="form-select" id="edit-menu" name="menu">
#                <option value="0">
#                 Choose a Department
#                </option>
#                <option value="http://www.bioe.neu.edu/">
#                 Bioengineering
#                </option>
#                <option value="http://www.che.neu.edu/">
#                 Chemical Engineering
#                </option>
#                <option value="http://www.civ.neu.edu/">
#                 Civil &amp; Environmental Engineering
#                </option>
#                <option value="http://www.ece.neu.edu/">
#                 Electrical &amp; Computer Engineering
#                </option>
#                <option value="http://www.mie.neu.edu/">
#                 Mechanical &amp; Industrial Engineering
#                </option>
#                <option value="/academics/depts/professional-master-science-degrees">
#                 Professional Master of Science Degrees
#                </option>
#               </select>
#              </div>
#              <input name="form_build_id" type="hidden" value="form-n0UiAxUaA6phsfUITI3KFe3khTjChqXyaUJqWcQpBKw"/>
#              <input name="form_id" type="hidden" value="nucoe_custom_menus_form"/>
#             </div>
#            </form>
#            <ul class="menu">
#             <li class="first expanded active menu-mlid-862">
#              <div class="expand-collapse">
#               ▼
#              </div>
#              <a class="active" href="/">
#               Prospective Students
#              </a>
#              <ul class="menu">
#               <li class="first leaf menu-mlid-912">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.northeastern.edu/campusmap/">
#                 Campus Map
#                </a>
#               </li>
#               <li class="leaf menu-mlid-1624">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.coe.neu.edu/apply">
#                 Apply
#                </a>
#               </li>
#               <li class="leaf active menu-mlid-920">
#                <div class="expand-collapse disabled">
#                </div>
#                <a class="active" href="/">
#                 News @ Northeastern
#                </a>
#               </li>
#               <li class="last leaf menu-mlid-1626">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.coe.neu.edu/community/student-life">
#                 Student Life
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li class="expanded active menu-mlid-863">
#              <div class="expand-collapse">
#               ▼
#              </div>
#              <a class="active" href="/">
#               Current Students
#              </a>
#              <ul class="menu">
#               <li class="first leaf menu-mlid-2420">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.coe.neu.edu/computer">
#                 COE Computer Center
#                </a>
#               </li>
#               <li class="leaf menu-mlid-1623">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="https://blackboard.neu.edu/">
#                 Blackboard
#                </a>
#               </li>
#               <li class="leaf menu-mlid-1754">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://myneu.neu.edu">
#                 myNEU
#                </a>
#               </li>
#               <li class="leaf menu-mlid-1780">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.coe.neu.edu/undergraduate-studies/undergraduate-academic-standards-and-appeals">
#                 Undergraduate Academic Standards and Appeals
#                </a>
#               </li>
#               <li class="leaf menu-mlid-2361">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.northeastern.edu/registrar/calendars.html">
#                 Academic Calendar
#                </a>
#               </li>
#               <li class="leaf menu-mlid-2360">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://northeastern.bncollege.com/">
#                 Bookstore
#                </a>
#               </li>
#               <li class="leaf menu-mlid-2366">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.campusrec.neu.edu/">
#                 Campus Recreation
#                </a>
#               </li>
#               <li class="leaf menu-mlid-2370">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.northeastern.edu/careers/">
#                 Career Development
#                </a>
#               </li>
#               <li class="leaf menu-mlid-2362">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.northeastern.edu/drc/">
#                 Disability Resource Center
#                </a>
#               </li>
#               <li class="leaf menu-mlid-2371">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.northeastern.edu/reslife/">
#                 Housing and Residential Life
#                </a>
#               </li>
#               <li class="leaf menu-mlid-2372">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.issi.neu.edu/">
#                 International Student and Scholar Institute
#                </a>
#               </li>
#               <li class="leaf menu-mlid-2365">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.lib.neu.edu/">
#                 Library
#                </a>
#               </li>
#               <li class="leaf menu-mlid-2363">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.northeastern.edu/registrar/">
#                 Registrar
#                </a>
#               </li>
#               <li class="leaf menu-mlid-2367">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.northeastern.edu/financialaid/">
#                 Student Financial Services
#                </a>
#               </li>
#               <li class="last leaf menu-mlid-2364">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.northeastern.edu/uhcs/">
#                 University Health and Counseling Services
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li class="expanded active menu-mlid-864">
#              <div class="expand-collapse">
#               ▼
#              </div>
#              <a class="active" href="/">
#               Alumni
#              </a>
#              <ul class="menu">
#               <li class="first leaf menu-mlid-925">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.alumni.northeastern.edu/">
#                 Husky Nation
#                </a>
#               </li>
#               <li class="leaf menu-mlid-2467">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.northeastern.edu/careers/services/alumni/">
#                 Career Services
#                </a>
#               </li>
#               <li class="last leaf menu-mlid-1755">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.northeastern.edu/empower/">
#                 Empower Campaign
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li class="expanded active menu-mlid-865">
#              <div class="expand-collapse">
#               ▼
#              </div>
#              <a class="active" href="/">
#               Faculty &amp; Staff
#              </a>
#              <ul class="menu">
#               <li class="first leaf menu-mlid-2353">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="https://sharepoint.neu.edu/NEUSites/Engineering/ARC/SitePages/Home.aspx">
#                 Administrative Resource Center
#                </a>
#               </li>
#               <li class="leaf menu-mlid-2421">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.coe.neu.edu/computer">
#                 COE Computer Center
#                </a>
#               </li>
#               <li class="leaf menu-mlid-2368">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://www.northeastern.edu/its/">
#                 Information Technology Services
#                </a>
#               </li>
#               <li class="leaf menu-mlid-874">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="https://blackboard.neu.edu/">
#                 Blackboard
#                </a>
#               </li>
#               <li class="leaf menu-mlid-1627">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="http://myneu.neu.edu">
#                 myNEU
#                </a>
#               </li>
#               <li class="last leaf menu-mlid-1630">
#                <div class="expand-collapse disabled">
#                </div>
#                <a href="https://sharepoint.neu.edu/NEUSites/Engineering/default.aspx">
#                 Intranet
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li class="last collapsed active menu-mlid-866">
#              <div class="expand-collapse disabled">
#              </div>
#              <a class="active" href="/">
#               Corporate Partners
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </div>
#       </section>
#       <section class="block block-search block-search-form header">
#        <form accept-charset="UTF-8" action="/" class="google-cse" id="search-block-form" method="post">
#         <div>
#          <div class="container-inline">
#           <h2 class="element-invisible">
#            Search form
#           </h2>
#           <div class="form-item form-type-textfield form-item-search-block-form">
#            <label class="element-invisible" for="edit-search-block-form--2">
#             Search
#            </label>
#            <input class="small-8 columns form-text" id="edit-search-block-form--2" maxlength="128" name="search_block_form" placeholder="Search" size="15" title="Enter the terms you wish to search for." type="text" value=""/>
#           </div>
#           <button class="postfix small-4 columns form-submit" id="edit-submit" name="op" type="submit" value="Search">
#            Search
#           </button>
#           <input name="form_build_id" type="hidden" value="form-sUyNp6OhqmeKinUbOv4_EupyG7V5Vf-J1tr_rL24n6g"/>
#           <input name="form_id" type="hidden" value="search_block_form"/>
#          </div>
#         </div>
#        </form>
#       </section>
#       <section class="block block-menu block-menu-menu-cta-links header">
#        <h2 class="block-title element-invisible">
#         Call to Action Links
#        </h2>
#        <ul class="menu">
#         <li class="first collapsed">
#          <a href="http://www.coe.neu.edu/connect">
#           Connect
#          </a>
#         </li>
#         <li class="leaf">
#          <a href="http://www.coe.neu.edu/apply">
#           Apply
#          </a>
#         </li>
#         <li class="last leaf">
#          <a href="http://www.giving.northeastern.edu/coe">
#           Give
#          </a>
#         </li>
#        </ul>
#       </section>
#      </div>
#     </section>
#     <!--/.l-header-region -->
#     <!--.l-navigation-region -->
#     <section class="l-navigation-region">
#      <section class="block block-nucoe-custom-menus block-nucoe-custom-menus-department-title">
#       <div class="department-header">
#        <div class="row">
#         <div class="department-sub">
#          Department of
#         </div>
#         <a class="title" href="/academics/depts/chemical-engineering">
#          Chemical Engineering
#         </a>
#         <span class="corner">
#         </span>
#        </div>
#       </div>
#      </section>
#      <section class="block block-nucoe-custom-menus block-nucoe-custom-menus-top-navigation">
#       <ul class="menu">
#        <li class="first expanded menu-mlid-962">
#         <a class="left stack-children" href="/che/about-chemical-engineering">
#          About
#         </a>
#         <ul class="menu">
#          <li class="first leaf menu-mlid-1424">
#           <a href="/che/mission-statement">
#            Mission Statement
#           </a>
#          </li>
#          <li class="leaf menu-mlid-2425">
#           <a href="/che/about/message-chair">
#            Message from the Chair
#           </a>
#          </li>
#          <li class="leaf menu-mlid-1408">
#           <a href="/che/department-history">
#            Department History
#           </a>
#          </li>
#          <li class="leaf menu-mlid-1404">
#           <a href="/che/contact-us">
#            Contact Us
#           </a>
#          </li>
#          <li class="leaf menu-mlid-1144">
#           <a href="/che/about/directory">
#            Directory
#           </a>
#          </li>
#          <li class="last leaf menu-mlid-1139">
#           <a href="/che/success">
#            Success Stories
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="expanded menu-mlid-967">
#         <a class="left " href="/che/degrees-programs">
#          Degrees &amp; Programs
#         </a>
#         <ul class="menu">
#          <li class="first expanded menu-mlid-1661">
#           <a href="/che/degrees-programs/undergraduate-studies">
#            Undergraduate Studies
#           </a>
#           <ul class="menu">
#            <li class="first leaf menu-mlid-1604">
#             <a href="/degrees/biochemical-engineering-minor">
#              Minor, Biochemical Engineering
#             </a>
#            </li>
#            <li class="leaf menu-mlid-1783">
#             <a href="/degrees/materials-science-and-engineering-minor">
#              Minor, Materials Science &amp; Engineering
#             </a>
#            </li>
#            <li class="leaf menu-mlid-1605">
#             <a href="/degrees/chemical-engineering-bs">
#              BS, Chemical Engineering
#             </a>
#            </li>
#            <li class="leaf menu-mlid-1610">
#             <a href="/degrees/chemical-engineering-and-physics-bs">
#              BS, Chemical Engineering &amp; Physics
#             </a>
#            </li>
#            <li class="leaf menu-mlid-1606">
#             <a href="/degrees/plusone-bs/ms-chemical-engineering">
#              BS/MS, Chemical Engineering
#             </a>
#            </li>
#            <li class="leaf menu-mlid-3787">
#             <a href="http://www.mie.neu.edu/degrees/plusone-bs/ms-engineering-management">
#              BS/MS, Engineering Management
#             </a>
#            </li>
#            <li class="leaf menu-mlid-1407">
#             <a href="/che/undergraduate-studies/accreditation">
#              Accreditation
#             </a>
#            </li>
#            <li class="last leaf menu-mlid-1406">
#             <a href="/che/capstone">
#              Capstone
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="last expanded menu-mlid-1611">
#           <a href="/che/degrees-programs/graduate-studies">
#            Graduate Studies
#           </a>
#           <ul class="menu">
#            <li class="first leaf menu-mlid-1607">
#             <a href="/degrees/master-science-chemical-engineering">
#              MS, Chemical Engineering
#             </a>
#            </li>
#            <li class="last leaf menu-mlid-1608">
#             <a href="/degrees/chemical-engineering-phd">
#              PhD, Chemical Engineering
#             </a>
#            </li>
#           </ul>
#          </li>
#         </ul>
#        </li>
#        <li class="expanded menu-mlid-977">
#         <a class="left, stack-children" href="/che/co-op-experiential-learning">
#          Co-op &amp; Experiential Learning
#         </a>
#         <ul class="menu">
#          <li class="first leaf menu-mlid-1422">
#           <a href="http://www.northeastern.edu/coop/students/faq/">
#            Co-op FAQs
#           </a>
#          </li>
#          <li class="expanded menu-mlid-1426">
#           <a href="/che/exchange-program">
#            Exchange Program
#           </a>
#           <ul class="menu">
#            <li class="first last leaf menu-mlid-3109">
#             <a href="/che/exchange-program/exchange-program-past-research-projects">
#              Exchange Program - Past Research Projects
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="leaf menu-mlid-1521">
#           <a href="/che/student-industry-bridge">
#            Student-Industry Bridge
#           </a>
#          </li>
#          <li class="leaf menu-mlid-3502">
#           <a href="/che/co-op-experiential-learning/co-op-coordinators">
#            Co-op Coordinators
#           </a>
#          </li>
#          <li class="last leaf menu-mlid-4839">
#           <a href="/che/co-op-experiential-learning/international-research">
#            International Research
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="expanded menu-mlid-982">
#         <a href="/che/faculty-research">
#          Faculty &amp; Research
#         </a>
#         <ul class="menu">
#          <li class="first expanded menu-mlid-4179">
#           <a href="/che/faculty-research/faculty">
#            Faculty
#           </a>
#           <ul class="menu">
#            <li class="first leaf menu-mlid-2117">
#             <a href="/che/faculty/directory">
#              Faculty Directory
#             </a>
#            </li>
#            <li class="leaf menu-mlid-2717">
#             <a href="/che/faculty-directory/honors-and-distinctions">
#              Honors and Distinctions
#             </a>
#            </li>
#            <li class="last leaf menu-mlid-2429">
#             <a href="/che/faculty/scholarship-reports">
#              Scholarship Reports
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="last expanded menu-mlid-1412">
#           <a href="/che/research-areas">
#            Research Areas
#           </a>
#           <ul class="menu">
#            <li class="first leaf menu-mlid-2121">
#             <a href="/che/research/advanced-materials">
#              Advanced Materials Research
#             </a>
#            </li>
#            <li class="last leaf menu-mlid-2122">
#             <a href="/che/research/biological-engineering">
#              Biological Engineering
#             </a>
#            </li>
#           </ul>
#          </li>
#         </ul>
#        </li>
#        <li class="expanded menu-mlid-972">
#         <a class="left, stack-children" href="/che/community">
#          Community
#         </a>
#         <ul class="menu">
#          <li class="first leaf menu-mlid-2942">
#           <a href="/che/newsletters">
#            Alumni Newsletters
#           </a>
#          </li>
#          <li class="leaf menu-mlid-1423">
#           <a href="/che/alumni">
#            IAB Directory
#           </a>
#          </li>
#          <li class="leaf menu-mlid-1409">
#           <a href="/che/community/orgs">
#            Student Groups
#           </a>
#          </li>
#          <li class="leaf menu-mlid-3765">
#           <a href="/che/community/writing-center">
#            Writing Center
#           </a>
#          </li>
#          <li class="last leaf menu-mlid-4302">
#           <a href="http://www.nuche1on1.com/" target="_blank">
#            1on1 Mentoring
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="last expanded menu-mlid-1414">
#         <a class="right" href="/che/news-events">
#          News &amp; Events
#         </a>
#         <ul class="menu">
#          <li class="first expanded menu-mlid-1070">
#           <a href="/academics/depts/chemical-engineering/news">
#            News
#           </a>
#           <ul class="menu">
#            <li class="first leaf menu-mlid-4817">
#             <a href="/che/in-the-media">
#              In the Media
#             </a>
#            </li>
#            <li class="leaf menu-mlid-4816">
#             <a href="/che/blog">
#              Blog
#             </a>
#            </li>
#            <li class="collapsed menu-mlid-1425">
#             <a href="/che/award-ceremonies">
#              Award Ceremonies
#             </a>
#            </li>
#            <li class="last leaf menu-mlid-1787">
#             <a href="/che/newsletters">
#              Newsletters
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="last expanded menu-mlid-1523">
#           <a href="/che/events">
#            Events
#           </a>
#           <ul class="menu">
#            <li class="first last leaf menu-mlid-1427">
#             <a href="/che/guest-graduate-seminars">
#              Guest &amp; Graduate Seminars
#             </a>
#            </li>
#           </ul>
#          </li>
#         </ul>
#        </li>
#       </ul>
#      </section>
#      <section class="block block-nucoe-social-icons block-nucoe-social-icons-social-icons-header">
#       <h2 class="block-title">
#        Chemical Engineering
#       </h2>
#       <div class="view view-social-icons view-id-social_icons view-display-id-custom view-dom-id-4eb8dfeac6c995605ec70db7b51eeeb6">
#        <div class="view-content">
#         <div class="views-row views-row-1 views-row-odd views-row-first">
#          <div>
#           <div class="facebook icon">
#            <a href="https://www.facebook.com/neucheme/" target="_blank">
#             https://www.facebook.com/neucheme/
#            </a>
#           </div>
#          </div>
#         </div>
#         <div class="views-row views-row-2 views-row-even views-row-last">
#          <div>
#           <div class="twitter icon">
#            <a href="https://twitter.com/NU_ChemE" target="_blank">
#             https://twitter.com/NU_ChemE
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </section>
#     </section>
#     <!--/.l-navigation-region -->
#    </header>
#    <!--/.l-header -->
#    <div class="main-content">
#     <!-- Content Area Wrapper -->
#     <div class="l-content-area small-12 medium-8 large-8 columns">
#      <!--/.featured -->
#      <section class="l-featured">
#       <div class="featured-content">
#        <div class="field-collection-container clearfix">
#         <section class="block block-fieldblock block-fieldblock-node-department-default-field-nucoe-slider">
#          <div class="nucoe-slider slider-home slider-main">
#           <div class="nucoe-slider-slide">
# ...
#                 </span>
#                </div>
#               </div>
#               <div class="views-field views-field-title">
#                <span class="field-content">
#                 <a href="/news/che-students-awarded-ms-degrees">
#                  ChE Students Awarded MS Degrees
#                 </a>
#                </span>
#               </div>
#               <div class="views-field views-field-body">
#                <div class="field-content">
#                 <p>
#                  The following students are congratulated on completing their Master of Science degrees in December 2017: Yiping Fan, Jiachen Li, and Lili Liu. Adedokun Adedoyinand Stanley Chung are also awarded MS...
#                 </p>
#                </div>
#               </div>
#              </div>
#              <div class="views-row views-row-3 views-row-odd">
#               <div class="views-field views-field-field-nucoe-date">
#                <div class="field-content">
#                 <span class="date-display-single">
#                  January 18, 2018
#                 </span>
#                </div>
#               </div>
#               <div class="views-field views-field-title">
#                <span class="field-content">
#                 <a href="/news/fulbright-scholar-jos%C3%A9-miguel-garc%C3%ADa-collaborates-develop-nanomaterials">
#                  Fulbright Scholar José Miguel García Collaborates to Develop Nanomaterials
#                 </a>
#                </span>
#               </div>
#               <div class="views-field views-field-body">
#                <div class="field-content">
#                 <p>
#                  José Miguel García Martín, a research scientist at the Institute of Micro and Nanotechnology at the Spanish Research Council in Madrid, Spain, spent three months as a Fulbright Scholar in ChE...
#                 </p>
#                </div>
#               </div>
#              </div>
#              <div class="views-row views-row-4 views-row-even views-row-last">
#               <div class="views-field views-field-field-nucoe-date">
#                <div class="field-content">
#                 <span class="date-display-single">
#                  January 18, 2018
#                 </span>
#                </div>
#               </div>
#               <div class="views-field views-field-title">
#                <span class="field-content">
#                 <a href="/news/annabi-awarded-2nd-nih-r01-grant">
#                  Annabi Awarded 2nd NIH R01 Grant
#                 </a>
#                </span>
#               </div>
#               <div class="views-field views-field-body">
#                <div class="field-content">
#                 <p>
#                  ChE Assistant Professor Nasim Annabi received her second R01 grant ($3.1M) from the National Institutes of Health for a project entitled "Engineering highly elastic surgical sealants with hemostatic properties".
#                 </p>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="more-link">
#              <a href="/academics/depts/chemical-engineering/news">
#               View all News
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </section>
#      </aside>
#     </div>
#     <!-- end second sidebar -->
#    </div>
#    <!-- end main content -->
#    <!--.l-footer-->
#    <footer class="l-footer panel" role="contentinfo">
#     <!--.footer-rows -->
#     <div class="footer-zero">
#      <div class="row">
#       <section class="block block-menu block-menu-menu-cta-links--2">
#        <h2 class="block-title">
#         Call to Action Links
#        </h2>
#        <ul class="menu">
#         <li class="first collapsed">
#          <a href="http://www.coe.neu.edu/connect">
#           Connect
#          </a>
#         </li>
#         <li class="leaf">
#          <a href="http://www.coe.neu.edu/apply">
#           Apply
#          </a>
#         </li>
#         <li class="last leaf">
#          <a href="http://www.giving.northeastern.edu/coe">
#           Give
#          </a>
#         </li>
#        </ul>
#       </section>
#      </div>
#     </div>
#     <div class="footer-first">
#      <div class="row">
#       <section class="block block-nucoe-custom-menus block-nucoe-custom-menus-footer-menu">
#        <ul class="menu">
#         <li class="first expanded menu-mlid-962">
#          <a class="left stack-children" href="/che/about-chemical-engineering">
#           About
#          </a>
#          <ul class="menu">
#           <li class="first leaf menu-mlid-1424">
#            <a href="/che/mission-statement">
#             Mission Statement
#            </a>
#           </li>
#           <li class="leaf menu-mlid-2425">
#            <a href="/che/about/message-chair">
#             Message from the Chair
#            </a>
#           </li>
#           <li class="leaf menu-mlid-1408">
#            <a href="/che/department-history">
#             Department History
#            </a>
#           </li>
#           <li class="leaf menu-mlid-1404">
#            <a href="/che/contact-us">
#             Contact Us
#            </a>
#           </li>
#           <li class="leaf menu-mlid-1144">
#            <a href="/che/about/directory">
#             Directory
#            </a>
#           </li>
#           <li class="last leaf menu-mlid-1139">
#            <a href="/che/success">
#             Success Stories
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="expanded menu-mlid-967">
#          <a class="left " href="/che/degrees-programs">
#           Degrees &amp; Programs
#          </a>
#          <ul class="menu">
#           <li class="first collapsed menu-mlid-1661">
#            <a href="/che/degrees-programs/undergraduate-studies">
#             Undergraduate Studies
#            </a>
#           </li>
#           <li class="last collapsed menu-mlid-1611">
#            <a href="/che/degrees-programs/graduate-studies">
#             Graduate Studies
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="expanded menu-mlid-977">
#          <a class="left, stack-children" href="/che/co-op-experiential-learning">
#           Co-op &amp; Experiential Learning
#          </a>
#          <ul class="menu">
#           <li class="first leaf menu-mlid-1422">
#            <a href="http://www.northeastern.edu/coop/students/faq/">
#             Co-op FAQs
#            </a>
#           </li>
#           <li class="collapsed menu-mlid-1426">
#            <a href="/che/exchange-program">
#             Exchange Program
#            </a>
#           </li>
#           <li class="leaf menu-mlid-1521">
#            <a href="/che/student-industry-bridge">
#             Student-Industry Bridge
#            </a>
#           </li>
#           <li class="leaf menu-mlid-3502">
#            <a href="/che/co-op-experiential-learning/co-op-coordinators">
#             Co-op Coordinators
#            </a>
#           </li>
#           <li class="last leaf menu-mlid-4839">
#            <a href="/che/co-op-experiential-learning/international-research">
#             International Research
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="expanded menu-mlid-982">
#          <a href="/che/faculty-research">
#           Faculty &amp; Research
#          </a>
#          <ul class="menu">
#           <li class="first collapsed menu-mlid-4179">
#            <a href="/che/faculty-research/faculty">
#             Faculty
#            </a>
#           </li>
#           <li class="last collapsed menu-mlid-1412">
#            <a href="/che/research-areas">
#             Research Areas
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="expanded menu-mlid-972">
#          <a class="left, stack-children" href="/che/community">
#           Community
#          </a>
#          <ul class="menu">
#           <li class="first leaf menu-mlid-2942">
#            <a href="/che/newsletters">
#             Alumni Newsletters
#            </a>
#           </li>
#           <li class="leaf menu-mlid-1423">
#            <a href="/che/alumni">
#             IAB Directory
#            </a>
#           </li>
#           <li class="leaf menu-mlid-1409">
#            <a href="/che/community/orgs">
#             Student Groups
#            </a>
#           </li>
#           <li class="leaf menu-mlid-3765">
#            <a href="/che/community/writing-center">
#             Writing Center
#            </a>
#           </li>
#           <li class="last leaf menu-mlid-4302">
#            <a href="http://www.nuche1on1.com/" target="_blank">
#             1on1 Mentoring
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="last expanded menu-mlid-1414">
#          <a class="right" href="/che/news-events">
#           News &amp; Events
#          </a>
#          <ul class="menu">
#           <li class="first collapsed menu-mlid-1070">
#            <a href="/academics/depts/chemical-engineering/news">
#             News
#            </a>
#           </li>
#           <li class="last collapsed menu-mlid-1523">
#            <a href="/che/events">
#             Events
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </section>
#      </div>
#     </div>
#     <div class="footer-second">
#      <div class="row">
#       <section class="block block-search block-search-form--2">
#        <form accept-charset="UTF-8" action="/" class="google-cse" id="search-block-form--2" method="post">
#         <div>
#          <div class="container-inline">
#           <h2 class="element-invisible">
#            Search form
#           </h2>
#           <div class="form-item form-type-textfield form-item-search-block-form">
#            <label class="element-invisible" for="edit-search-block-form--4">
#             Search
#            </label>
#            <input class="small-8 columns form-text" id="edit-search-block-form--4" maxlength="128" name="search_block_form" placeholder="Search" size="15" title="Enter the terms you wish to search for." type="text" value=""/>
#           </div>
#           <button class="postfix small-4 columns form-submit" id="edit-submit--2" name="op" type="submit" value="Search">
#            Search
#           </button>
#           <input name="form_build_id" type="hidden" value="form-ppAA9yV6d1rQhzOPBo9nE7uqw0ly-udzxUbU4bnRoZY"/>
#           <input name="form_id" type="hidden" value="search_block_form"/>
#          </div>
#         </div>
#        </form>
#       </section>
#       <section class="block block-nucoe-social-icons block-nucoe-social-icons-social-icons-footer">
#        <h2 class="block-title">
#         Chemical Engineering
#        </h2>
#        <div class="view view-social-icons view-id-social_icons view-display-id-custom view-dom-id-9a39a5105c6fe99746f3c52428308459">
#         <div class="view-content">
#          <div class="views-row views-row-1 views-row-odd views-row-first">
#           <div>
#            <div class="facebook icon">
#             <a href="https://www.facebook.com/neucheme/" target="_blank">
#              https://www.facebook.com/neucheme/
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="views-row views-row-2 views-row-even views-row-last">
#           <div>
#            <div class="twitter icon">
#             <a href="https://twitter.com/NU_ChemE" target="_blank">
#              https://twitter.com/NU_ChemE
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </section>
#       <section class="block block-nucoe-social-icons block-nucoe-social-icons-social-icons-global-footer">
#        <h2 class="block-title">
#         College of Engineering
#        </h2>
#        <div class="view view-social-icons view-id-social_icons view-display-id-custom view-dom-id-e5e63a83465bb50c0a5cfec66b2b5b8f">
#         <div class="view-content">
#          <div class="views-row views-row-1 views-row-odd views-row-first">
#           <div>
#            <div class="facebook icon">
#             <a href="http://www.facebook.com/nucoe" target="_blank">
#              http://www.facebook.com/nucoe
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="views-row views-row-2 views-row-even">
#           <div>
#            <div class="twitter icon">
#             <a href="https://twitter.com/NortheasternCOE" target="_blank">
#              https://twitter.com/NortheasternCOE
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="views-row views-row-3 views-row-odd">
#           <div>
#            <div class="youtube icon">
#             <a href="http://www.youtube.com/northeasternengineer" target="_blank">
#              http://www.youtube.com/northeasternengineer
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="views-row views-row-4 views-row-even">
#           <div>
#            <div class="linkedin icon">
#             <a href="http://www.linkedin.com/company/northeastern-university---college-of-engineering" target="_blank">
#              http://www.linkedin.com/company/northeastern-university---college-of-engineering
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="views-row views-row-5 views-row-odd views-row-last">
#           <div>
#            <div class="instagram icon">
#             <a href="https://www.instagram.com/nucoe/" target="_blank">
#              https://www.instagram.com/nucoe/
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </section>
#      </div>
#     </div>
#     <div class="footer-third">
#      <div class="row">
#       <section class="block block-boxes block-boxes-simple block-boxes-nu-footer">
#        <div class="boxes-box" id="boxes-box-nu_footer">
#         <div class="boxes-box-content">
#          <div class="nu-footer__left">
#           <a class="nu-footer__title" href="http://www.northeastern.edu">
#           </a>
#          </div>
#          <div class="nu-footer__right">
#           <ul class="nu-footer__links">
#            <li>
#             <a href="http://my.northeastern.edu/">
#              myNortheastern
#             </a>
#            </li>
#            <li>
#             <a href="http://www.northeastern.edu/findfacultystaff">
#              Find Faculty &amp; Staff
#             </a>
#            </li>
#            <li>
#             <a href="http://www.northeastern.edu/neuhome/adminlinks/findaz.html">
#              Find A-Z
#             </a>
#            </li>
#            <li>
#             <a href="http://www.northeastern.edu/emergency/index.html">
#              Emergency Information
#             </a>
#            </li>
#            <li>
#             <a href="http://www.northeastern.edu/search/index.html">
#              Search
#             </a>
#            </li>
#            <li>
#             <a href="http://assistive.usablenet.com/tt/http://www.northeastern.edu/index.html">
#              Text Only
#             </a>
#            </li>
#           </ul>
#           <p class="nu-footer__copy">
#            360 Huntington Ave., Boston, Massachusetts 02115 • 617.373.2000 • TTY 617.373.3768
#           </p>
#          </div>
#         </div>
#        </div>
#       </section>
#      </div>
#     </div>
#    </footer>
#   </div>
#  </body>
# </html>
# ©2012 Northeastern University
# <!--/.footer-columns-->
# <!--/.footer-->
# <!--/.page -->
# <script src="http://www.che.neu.edu/sites/default/files/js/js_7Ukqb3ierdBEL0eowfOKzTkNu-Le97OPm-UqTS5NENU.js">
# </script>
# <script>
#  (function ($, Drupal, window, document, undefined) {
#       $(document).foundation();
#     })(jQuery, Drupal, this, this.document);
# </script>
# <script type="”text/javascript”">
#  var _gaq = _gaq || [];
#     _gaq.push([’_setAccount’, ‘UA-1768083-1’]);
#     _gaq.push([’_trackPageview’]);
#     (function()
#     { var ga = document.createElement(‘script’); ga.type = ‘text/javascript’; ga.async = true; ga.src = (‘https:’ == document.location.protocol ? ‘https://ssl’; : ‘http://www’;) + ’.google-analytics.com/ga.js’; var s = document.getElementsByTagName(‘script’)[0]; s.parentNode.insertBefore(ga, s); }
#     )();
#     document.write(unescape("%3Cscript src='//munchkin.marketo.net/munchkin.js' type='text/javascript'%3E%3C/script%3E"));
#     Munchkin.init('169-AQM-381',{"wsInfo":"hlRQ"});
# </script>

# %%
# Collecting all the link on the page
all_link_on_page = soup.find_all('a')
for link in all_link_on_page:
    print(link.get('href'))
# Out:
# #main-content
# http://www.coe.neu.edu/
# /che/about-chemical-engineering
# /che/mission-statement
# /che/about/message-chair
# /che/department-history
# /che/contact-us
# /che/about/directory
# /che/success
# /che/degrees-programs
# /che/degrees-programs/undergraduate-studies
# /degrees/biochemical-engineering-minor
# /degrees/materials-science-and-engineering-minor
# /degrees/chemical-engineering-bs
# /degrees/chemical-engineering-and-physics-bs
# /degrees/plusone-bs/ms-chemical-engineering
# http://www.mie.neu.edu/degrees/plusone-bs/ms-engineering-management
# /che/undergraduate-studies/accreditation
# /che/capstone
# /che/degrees-programs/graduate-studies
# /degrees/master-science-chemical-engineering
# /degrees/chemical-engineering-phd
# /che/co-op-experiential-learning
# http://www.northeastern.edu/coop/students/faq/
# /che/exchange-program
# /che/exchange-program/exchange-program-past-research-projects
# /che/student-industry-bridge
# /che/co-op-experiential-learning/co-op-coordinators
# /che/co-op-experiential-learning/international-research
# /che/faculty-research
# /che/faculty-research/faculty
# /che/faculty/directory
# /che/faculty-directory/honors-and-distinctions
# /che/faculty/scholarship-reports
# /che/research-areas
# /che/research/advanced-materials
# /che/research/biological-engineering
# /che/community
# /che/newsletters
# /che/alumni
# /che/community/orgs
# /che/community/writing-center
# http://www.nuche1on1.com/
# /che/news-events
# /academics/depts/chemical-engineering/news
# /che/in-the-media
# /che/blog
# /che/award-ceremonies
# /che/newsletters
# /che/events
# /che/guest-graduate-seminars
# http://www.coe.neu.edu/why-coe/about-college
# http://www.coe.neu.edu/why-coe
# http://www.coe.neu.edu/why-coe/engineering-leadership
# http://www.coe.neu.edu/about-college/prospective-students
# http://www.coe.neu.edu/about-college/current-students
# http://www.coe.neu.edu/about-college/faculty-staff
# http://www.coe.neu.edu/about-college/corporate-partners
# http://www.coe.neu.edu/co-op-experiential-learning
# http://www.coe.neu.edu/news-events
# /
# http://www.northeastern.edu/campusmap/
# http://www.coe.neu.edu/apply
# /
# http://www.coe.neu.edu/community/student-life
# /
# http://www.coe.neu.edu/computer
# https://blackboard.neu.edu/
# http://myneu.neu.edu
# http://www.coe.neu.edu/undergraduate-studies/undergraduate-academic-standards-and-appeals
# http://www.northeastern.edu/registrar/calendars.html
# http://northeastern.bncollege.com/
# http://www.campusrec.neu.edu/
# http://www.northeastern.edu/careers/
# http://www.northeastern.edu/drc/
# http://www.northeastern.edu/reslife/
# http://www.issi.neu.edu/
# http://www.lib.neu.edu/
# http://www.northeastern.edu/registrar/
# http://www.northeastern.edu/financialaid/
# http://www.northeastern.edu/uhcs/
# /
# http://www.alumni.northeastern.edu/
# http://www.northeastern.edu/careers/services/alumni/
# http://www.northeastern.edu/empower/
# /
# https://sharepoint.neu.edu/NEUSites/Engineering/ARC/SitePages/Home.aspx
# http://www.coe.neu.edu/computer
# http://www.northeastern.edu/its/
# https://blackboard.neu.edu/
# http://myneu.neu.edu
# https://sharepoint.neu.edu/NEUSites/Engineering/default.aspx
# /
# http://www.coe.neu.edu/connect
# http://www.coe.neu.edu/apply
# http://www.giving.northeastern.edu/coe
# /academics/depts/chemical-engineering
# /che/about-chemical-engineering
# /che/mission-statement
# /che/about/message-chair
# /che/department-history
# /che/contact-us
# /che/about/directory
# /che/success
# /che/degrees-programs
# /che/degrees-programs/undergraduate-studies
# /degrees/biochemical-engineering-minor
# /degrees/materials-science-and-engineering-minor
# /degrees/chemical-engineering-bs
# /degrees/chemical-engineering-and-physics-bs
# /degrees/plusone-bs/ms-chemical-engineering
# http://www.mie.neu.edu/degrees/plusone-bs/ms-engineering-management
# /che/undergraduate-studies/accreditation
# /che/capstone
# /che/degrees-programs/graduate-studies
# /degrees/master-science-chemical-engineering
# /degrees/chemical-engineering-phd
# /che/co-op-experiential-learning
# http://www.northeastern.edu/coop/students/faq/
# /che/exchange-program
# /che/exchange-program/exchange-program-past-research-projects
# /che/student-industry-bridge
# /che/co-op-experiential-learning/co-op-coordinators
# /che/co-op-experiential-learning/international-research
# /che/faculty-research
# /che/faculty-research/faculty
# /che/faculty/directory
# /che/faculty-directory/honors-and-distinctions
# /che/faculty/scholarship-reports
# /che/research-areas
# /che/research/advanced-materials
# /che/research/biological-engineering
# /che/community
# /che/newsletters
# /che/alumni
# /che/community/orgs
# /che/community/writing-center
# http://www.nuche1on1.com/
# /che/news-events
# /academics/depts/chemical-engineering/news
# /che/in-the-media
# /che/blog
# /che/award-ceremonies
# /che/newsletters
# /che/events
# /che/guest-graduate-seminars
# https://www.facebook.com/neucheme/
# https://twitter.com/NU_ChemE
# http://www.che.neu.edu/news/surgical-glue-can-seal-wounds-seconds
# http://www.che.neu.edu/news/surgical-glue-can-seal-wounds-seconds
# http://www.che.neu.edu/news/surgical-glue-can-seal-wounds-seconds
# http://www.che.neu.edu/news/researcher-and-entrepreneur
# http://www.che.neu.edu/news/researcher-and-entrepreneur
# http://www.che.neu.edu/news/researcher-and-entrepreneur
# http://www.che.neu.edu/news/big-health-innovation-nano-scale
# http://www.che.neu.edu/news/big-health-innovation-nano-scale
# http://www.che.neu.edu/news/big-health-innovation-nano-scale
# http://www.ece.neu.edu/news/harris-receives-8m-darpa-grant-magnets
# http://www.ece.neu.edu/news/harris-receives-8m-darpa-grant-magnets
# http://www.ece.neu.edu/news/harris-receives-8m-darpa-grant-magnets
# None
# http://www.coe.neu.edu/events/negotiating-your-first-job-offer
# http://www.coe.neu.edu/events/national-bio/nano-innovation-seminar-menon-laboratories-inc-advanced-filtration-technologies
# http://www.coe.neu.edu/events/research-art-or-science-call-submissions-deadline
# /events/che-seminar-nmr-metal-organic-frameworks-dr-jeffrey-reimer
# /academics/depts/chemical-engineering/events
# /news/che-faculty-featured-42nd-advanced-ceramics-composites-conference
# /news/che-students-awarded-ms-degrees
# /news/fulbright-scholar-jos%C3%A9-miguel-garc%C3%ADa-collaborates-develop-nanomaterials
# /news/annabi-awarded-2nd-nih-r01-grant
# /academics/depts/chemical-engineering/news
# http://www.coe.neu.edu/connect
# http://www.coe.neu.edu/apply
# http://www.giving.northeastern.edu/coe
# /che/about-chemical-engineering
# /che/mission-statement
# /che/about/message-chair
# /che/department-history
# /che/contact-us
# /che/about/directory
# /che/success
# /che/degrees-programs
# /che/degrees-programs/undergraduate-studies
# /che/degrees-programs/graduate-studies
# /che/co-op-experiential-learning
# http://www.northeastern.edu/coop/students/faq/
# /che/exchange-program
# /che/student-industry-bridge
# /che/co-op-experiential-learning/co-op-coordinators
# /che/co-op-experiential-learning/international-research
# /che/faculty-research
# /che/faculty-research/faculty
# /che/research-areas
# /che/community
# /che/newsletters
# /che/alumni
# /che/community/orgs
# /che/community/writing-center
# http://www.nuche1on1.com/
# /che/news-events
# /academics/depts/chemical-engineering/news
# /che/events
# https://www.facebook.com/neucheme/
# https://twitter.com/NU_ChemE
# http://www.facebook.com/nucoe
# https://twitter.com/NortheasternCOE
# http://www.youtube.com/northeasternengineer
# http://www.linkedin.com/company/northeastern-university---college-of-engineering
# https://www.instagram.com/nucoe/
# http://www.northeastern.edu
# http://my.northeastern.edu/
# http://www.northeastern.edu/findfacultystaff
# http://www.northeastern.edu/neuhome/adminlinks/findaz.html
# http://www.northeastern.edu/emergency/index.html
# http://www.northeastern.edu/search/index.html
# http://assistive.usablenet.com/tt/http://www.northeastern.edu/index.html

# %%
#Getting the URL and the Text
for social_name in all_link_on_page:
    if social_name.get('href') == None:
        continue
    else:
        links = social_name.get('href')
        names = social_name.text
        print(links)
        print(names)
# Out:
# #main-content
# Skip to main content
# http://www.coe.neu.edu/
#
# /che/about-chemical-engineering
# About
# /che/mission-statement
# Mission Statement
# /che/about/message-chair
# Message from the Chair
# /che/department-history
# Department History
# /che/contact-us
# Contact Us
# /che/about/directory
# Directory
# /che/success
# Success Stories
# /che/degrees-programs
# Degrees & Programs
# /che/degrees-programs/undergraduate-studies
# Undergraduate Studies
# /degrees/biochemical-engineering-minor
# Minor, Biochemical Engineering
# /degrees/materials-science-and-engineering-minor
# Minor, Materials Science & Engineering
# /degrees/chemical-engineering-bs
# BS, Chemical Engineering
# /degrees/chemical-engineering-and-physics-bs
# BS, Chemical Engineering & Physics
# /degrees/plusone-bs/ms-chemical-engineering
# BS/MS, Chemical Engineering
# http://www.mie.neu.edu/degrees/plusone-bs/ms-engineering-management
# BS/MS, Engineering Management
# /che/undergraduate-studies/accreditation
# Accreditation
# /che/capstone
# Capstone
# /che/degrees-programs/graduate-studies
# Graduate Studies
# /degrees/master-science-chemical-engineering
# MS, Chemical Engineering
# /degrees/chemical-engineering-phd
# PhD, Chemical Engineering
# /che/co-op-experiential-learning
# Co-op & Experiential Learning
# http://www.northeastern.edu/coop/students/faq/
# Co-op FAQs
# /che/exchange-program
# Exchange Program
# /che/exchange-program/exchange-program-past-research-projects
# Exchange Program - Past Research Projects
# /che/student-industry-bridge
# Student-Industry Bridge
# /che/co-op-experiential-learning/co-op-coordinators
# Co-op Coordinators
# /che/co-op-experiential-learning/international-research
# International Research
# /che/faculty-research
# Faculty & Research
# /che/faculty-research/faculty
# Faculty
# /che/faculty/directory
# Faculty Directory
# /che/faculty-directory/honors-and-distinctions
# Honors and Distinctions
# /che/faculty/scholarship-reports
# Scholarship Reports
# /che/research-areas
# Research Areas
# /che/research/advanced-materials
# Advanced Materials Research
# /che/research/biological-engineering
# Biological Engineering
# /che/community
# Community
# /che/newsletters
# Alumni Newsletters
# /che/alumni
# IAB Directory
# /che/community/orgs
# Student Groups
# /che/community/writing-center
# Writing Center
# http://www.nuche1on1.com/
# 1on1 Mentoring
# /che/news-events
# News & Events
# /academics/depts/chemical-engineering/news
# News
# /che/in-the-media
# In the Media
# /che/blog
# Blog
# /che/award-ceremonies
# Award Ceremonies
# /che/newsletters
# Newsletters
# /che/events
# Events
# /che/guest-graduate-seminars
# Guest & Graduate Seminars
# http://www.coe.neu.edu/why-coe/about-college
# About
# http://www.coe.neu.edu/why-coe
# Why COE?
# http://www.coe.neu.edu/why-coe/engineering-leadership
# College Leadership
# http://www.coe.neu.edu/about-college/prospective-students
# Info for Prospective Students
# http://www.coe.neu.edu/about-college/current-students
# Info for Current Students
# http://www.coe.neu.edu/about-college/faculty-staff
# Info for Faculty & Staff
# http://www.coe.neu.edu/about-college/corporate-partners
# Info for Corporate Partners
# http://www.coe.neu.edu/co-op-experiential-learning
# Co-op & Experiential Learning
# http://www.coe.neu.edu/news-events
# News & Events
# /
# Prospective Students
# http://www.northeastern.edu/campusmap/
# Campus Map
# http://www.coe.neu.edu/apply
# Apply
# /
# News @ Northeastern
# http://www.coe.neu.edu/community/student-life
# Student Life
# /
# Current Students
# http://www.coe.neu.edu/computer
# COE Computer Center
# https://blackboard.neu.edu/
# Blackboard
# http://myneu.neu.edu
# myNEU
# http://www.coe.neu.edu/undergraduate-studies/undergraduate-academic-standards-and-appeals
# Undergraduate Academic Standards and Appeals
# http://www.northeastern.edu/registrar/calendars.html
# Academic Calendar
# http://northeastern.bncollege.com/
# Bookstore
# http://www.campusrec.neu.edu/
# Campus Recreation
# http://www.northeastern.edu/careers/
# Career Development
# http://www.northeastern.edu/drc/
# Disability Resource Center
# http://www.northeastern.edu/reslife/
# Housing and Residential Life
# http://www.issi.neu.edu/
# International Student and Scholar Institute
# http://www.lib.neu.edu/
# Library
# http://www.northeastern.edu/registrar/
# Registrar
# http://www.northeastern.edu/financialaid/
# Student Financial Services
# http://www.northeastern.edu/uhcs/
# University Health and Counseling Services
# /
# Alumni
# http://www.alumni.northeastern.edu/
# Husky Nation
# http://www.northeastern.edu/careers/services/alumni/
# Career Services
# http://www.northeastern.edu/empower/
# Empower Campaign
# /
# Faculty & Staff
# https://sharepoint.neu.edu/NEUSites/Engineering/ARC/SitePages/Home.aspx
# Administrative Resource Center
# http://www.coe.neu.edu/computer
# COE Computer Center
# http://www.northeastern.edu/its/
# Information Technology Services
# https://blackboard.neu.edu/
# Blackboard
# http://myneu.neu.edu
# myNEU
# https://sharepoint.neu.edu/NEUSites/Engineering/default.aspx
# Intranet
# /
# Corporate Partners
# http://www.coe.neu.edu/connect
# Connect
# http://www.coe.neu.edu/apply
# Apply
# http://www.giving.northeastern.edu/coe
# Give
# /academics/depts/chemical-engineering
# Chemical Engineering
# /che/about-chemical-engineering
# About
# /che/mission-statement
# Mission Statement
# /che/about/message-chair
# Message from the Chair
# /che/department-history
# Department History
# /che/contact-us
# Contact Us
# /che/about/directory
# Directory
# /che/success
# Success Stories
# /che/degrees-programs
# Degrees & Programs
# /che/degrees-programs/undergraduate-studies
# Undergraduate Studies
# /degrees/biochemical-engineering-minor
# Minor, Biochemical Engineering
# /degrees/materials-science-and-engineering-minor
# Minor, Materials Science & Engineering
# /degrees/chemical-engineering-bs
# BS, Chemical Engineering
# /degrees/chemical-engineering-and-physics-bs
# BS, Chemical Engineering & Physics
# /degrees/plusone-bs/ms-chemical-engineering
# BS/MS, Chemical Engineering
# http://www.mie.neu.edu/degrees/plusone-bs/ms-engineering-management
# BS/MS, Engineering Management
# /che/undergraduate-studies/accreditation
# Accreditation
# /che/capstone
# Capstone
# /che/degrees-programs/graduate-studies
# Graduate Studies
# /degrees/master-science-chemical-engineering
# MS, Chemical Engineering
# /degrees/chemical-engineering-phd
# PhD, Chemical Engineering
# /che/co-op-experiential-learning
# Co-op & Experiential Learning
# http://www.northeastern.edu/coop/students/faq/
# Co-op FAQs
# /che/exchange-program
# Exchange Program
# /che/exchange-program/exchange-program-past-research-projects
# Exchange Program - Past Research Projects
# /che/student-industry-bridge
# Student-Industry Bridge
# /che/co-op-experiential-learning/co-op-coordinators
# Co-op Coordinators
# /che/co-op-experiential-learning/international-research
# International Research
# /che/faculty-research
# Faculty & Research
# /che/faculty-research/faculty
# Faculty
# /che/faculty/directory
# Faculty Directory
# /che/faculty-directory/honors-and-distinctions
# Honors and Distinctions
# /che/faculty/scholarship-reports
# Scholarship Reports
# /che/research-areas
# Research Areas
# /che/research/advanced-materials
# Advanced Materials Research
# /che/research/biological-engineering
# Biological Engineering
# /che/community
# Community
# /che/newsletters
# Alumni Newsletters
# /che/alumni
# IAB Directory
# /che/community/orgs
# Student Groups
# /che/community/writing-center
# Writing Center
# http://www.nuche1on1.com/
# 1on1 Mentoring
# /che/news-events
# News & Events
# /academics/depts/chemical-engineering/news
# News
# /che/in-the-media
# In the Media
# /che/blog
# Blog
# /che/award-ceremonies
# Award Ceremonies
# /che/newsletters
# Newsletters
# /che/events
# Events
# /che/guest-graduate-seminars
# Guest & Graduate Seminars
# https://www.facebook.com/neucheme/
# https://www.facebook.com/neucheme/
# https://twitter.com/NU_ChemE
# https://twitter.com/NU_ChemE
# http://www.che.neu.edu/news/surgical-glue-can-seal-wounds-seconds
#
# http://www.che.neu.edu/news/surgical-glue-can-seal-wounds-seconds
# Seal Wounds in Seconds
# http://www.che.neu.edu/news/surgical-glue-can-seal-wounds-seconds
# Read More
# http://www.che.neu.edu/news/researcher-and-entrepreneur
#
# http://www.che.neu.edu/news/researcher-and-entrepreneur
# Researcher and Entrepreneur
# http://www.che.neu.edu/news/researcher-and-entrepreneur
# Read More
# http://www.che.neu.edu/news/big-health-innovation-nano-scale
#
# http://www.che.neu.edu/news/big-health-innovation-nano-scale
# Health Innovation at a Nano Scale
# http://www.che.neu.edu/news/big-health-innovation-nano-scale
# Read More
# http://www.ece.neu.edu/news/harris-receives-8m-darpa-grant-magnets
#
# http://www.ece.neu.edu/news/harris-receives-8m-darpa-grant-magnets
# $8M DARPA Grant for MAGNETS
# http://www.ece.neu.edu/news/harris-receives-8m-darpa-grant-magnets
# Read More
# http://www.coe.neu.edu/events/negotiating-your-first-job-offer
# Negotiating your First Job Offer
# http://www.coe.neu.edu/events/national-bio/nano-innovation-seminar-menon-laboratories-inc-advanced-filtration-technologies
# National Bio/Nano Innovation Seminar - "Menon Laboratories Inc: Advanced Filtration Technologies"
# http://www.coe.neu.edu/events/research-art-or-science-call-submissions-deadline
# Research: Art or Science? Call for Submissions Deadline
# /events/che-seminar-nmr-metal-organic-frameworks-dr-jeffrey-reimer
# ChE Seminar: NMR & Metal-Organic Frameworks, Dr. Jeffrey A. Reimer
# /academics/depts/chemical-engineering/events
#
#     View all Events
# /news/che-faculty-featured-42nd-advanced-ceramics-composites-conference
# ChE Faculty featured at 42nd Advanced Ceramics & Composites Conference
# /news/che-students-awarded-ms-degrees
# ChE Students Awarded MS Degrees
# /news/fulbright-scholar-jos%C3%A9-miguel-garc%C3%ADa-collaborates-develop-nanomaterials
# Fulbright Scholar José Miguel García Collaborates to Develop Nanomaterials
# /news/annabi-awarded-2nd-nih-r01-grant
# Annabi Awarded 2nd NIH R01 Grant
# /academics/depts/chemical-engineering/news
#
#     View all News
# http://www.coe.neu.edu/connect
# Connect
# http://www.coe.neu.edu/apply
# Apply
# http://www.giving.northeastern.edu/coe
# Give
# /che/about-chemical-engineering
# About
# /che/mission-statement
# Mission Statement
# /che/about/message-chair
# Message from the Chair
# /che/department-history
# Department History
# /che/contact-us
# Contact Us
# /che/about/directory
# Directory
# /che/success
# Success Stories
# /che/degrees-programs
# Degrees & Programs
# /che/degrees-programs/undergraduate-studies
# Undergraduate Studies
# /che/degrees-programs/graduate-studies
# Graduate Studies
# /che/co-op-experiential-learning
# Co-op & Experiential Learning
# http://www.northeastern.edu/coop/students/faq/
# Co-op FAQs
# /che/exchange-program
# Exchange Program
# /che/student-industry-bridge
# Student-Industry Bridge
# /che/co-op-experiential-learning/co-op-coordinators
# Co-op Coordinators
# /che/co-op-experiential-learning/international-research
# International Research
# /che/faculty-research
# Faculty & Research
# /che/faculty-research/faculty
# Faculty
# /che/research-areas
# Research Areas
# /che/community
# Community
# /che/newsletters
# Alumni Newsletters
# /che/alumni
# IAB Directory
# /che/community/orgs
# Student Groups
# /che/community/writing-center
# Writing Center
# http://www.nuche1on1.com/
# 1on1 Mentoring
# /che/news-events
# News & Events
# /academics/depts/chemical-engineering/news
# News
# /che/events
# Events
# https://www.facebook.com/neucheme/
# https://www.facebook.com/neucheme/
# https://twitter.com/NU_ChemE
# https://twitter.com/NU_ChemE
# http://www.facebook.com/nucoe
# http://www.facebook.com/nucoe
# https://twitter.com/NortheasternCOE
# https://twitter.com/NortheasternCOE
# http://www.youtube.com/northeasternengineer
# http://www.youtube.com/northeasternengineer
# http://www.linkedin.com/company/northeastern-university---college-of-engineering
# http://www.linkedin.com/company/northeastern-university---college-of-engineering
# https://www.instagram.com/nucoe/
# https://www.instagram.com/nucoe/
# http://www.northeastern.edu
#
# http://my.northeastern.edu/
# myNortheastern
# http://www.northeastern.edu/findfacultystaff
# Find Faculty & Staff
# http://www.northeastern.edu/neuhome/adminlinks/findaz.html
# Find A-Z
# http://www.northeastern.edu/emergency/index.html
# Emergency Information
# http://www.northeastern.edu/search/index.html
# Search
# http://assistive.usablenet.com/tt/http://www.northeastern.edu/index.html
# Text Only

# %%
# Function to check link is valid or not
def check_valid_link(link):
    http = urllib3.PoolManager()
    response = http.request('GET',link)
    if response.status == 200:
        valid = True
        return valid

# %%
# Import data into Excel File
import xlwt
import time
from datetime import datetime
from tempfile import TemporaryFile
book = xlwt.Workbook()
sheet1 = book.add_sheet('sheet1')
sheet1.write(0,0,'External Links(URLs)')
sheet1.write(0,1,'Textual Description')
sheet1.write(0,2,'Validity')
sheet1.write(0,3,'Timestamp')
i=1
for social_name in all_link_on_page:
    if social_name.get('href') == None:
        continue
    else:
        links = 'http://www.che.neu.edu/' + social_name.get('href')
        names = social_name.text
        print(links)
        sheet1.write(i,0,links)
        print(names)
        sheet1.write(i,1,names) 
    isvalid = check_valid_link(links)
    print(isvalid)
    sheet1.write(i,2,isvalid)
    ts = time.time()
    q = datetime.fromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S')
    print(q)
    sheet1.write(i,3,q)
    i+=1
    
filename = "Scrapping.xls"
book.save(filename)
book.save(TemporaryFile())  
print('Excel sheet created')
# Out:
# http://www.che.neu.edu/#main-content
# Skip to main content
# True
# 2018-01-26 11:53:44
# http://www.che.neu.edu/http://www.coe.neu.edu/
#
# None
# 2018-01-26 11:53:45
# http://www.che.neu.edu//che/about-chemical-engineering
# About
# True
# 2018-01-26 11:53:45
# http://www.che.neu.edu//che/mission-statement
# Mission Statement
# True
# 2018-01-26 11:53:46
# http://www.che.neu.edu//che/about/message-chair
# Message from the Chair
# True
# 2018-01-26 11:53:46
# http://www.che.neu.edu//che/department-history
# Department History
# True
# 2018-01-26 11:53:47
# http://www.che.neu.edu//che/contact-us
# Contact Us
# True
# 2018-01-26 11:53:47
# http://www.che.neu.edu//che/about/directory
# Directory
# True
# 2018-01-26 11:53:49
# http://www.che.neu.edu//che/success
# Success Stories
# True
# 2018-01-26 11:53:50
# http://www.che.neu.edu//che/degrees-programs
# Degrees & Programs
# True
# 2018-01-26 11:53:51
# http://www.che.neu.edu//che/degrees-programs/undergraduate-studies
# Undergraduate Studies
# True
# 2018-01-26 11:53:51
# http://www.che.neu.edu//degrees/biochemical-engineering-minor
# Minor, Biochemical Engineering
# True
# 2018-01-26 11:53:52
# http://www.che.neu.edu//degrees/materials-science-and-engineering-minor
# Minor, Materials Science & Engineering
# True
# 2018-01-26 11:53:53
# http://www.che.neu.edu//degrees/chemical-engineering-bs
# BS, Chemical Engineering
# True
# 2018-01-26 11:53:53
# http://www.che.neu.edu//degrees/chemical-engineering-and-physics-bs
# BS, Chemical Engineering & Physics
# True
# 2018-01-26 11:53:54
# http://www.che.neu.edu//degrees/plusone-bs/ms-chemical-engineering
# BS/MS, Chemical Engineering
# True
# 2018-01-26 11:53:54
# http://www.che.neu.edu/http://www.mie.neu.edu/degrees/plusone-bs/ms-engineering-management
# BS/MS, Engineering Management
# None
# 2018-01-26 11:53:55
# http://www.che.neu.edu//che/undergraduate-studies/accreditation
# Accreditation
# True
# 2018-01-26 11:53:55
# http://www.che.neu.edu//che/capstone
# Capstone
# True
# 2018-01-26 11:53:56
# http://www.che.neu.edu//che/degrees-programs/graduate-studies
# Graduate Studies
# True
# 2018-01-26 11:53:57
# http://www.che.neu.edu//degrees/master-science-chemical-engineering
# MS, Chemical Engineering
# True
# 2018-01-26 11:53:57
# http://www.che.neu.edu//degrees/chemical-engineering-phd
# PhD, Chemical Engineering
# True
# 2018-01-26 11:53:58
